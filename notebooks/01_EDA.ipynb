# %% [markdown]
# # Objectives
# 1. ETA Prediction = customer satisfaction

# %% [markdown]
# # Imports

# %%
# Standard library
import os
import sys
import time
import json
import tempfile
import platform
import requests
import subprocess
from pathlib import Path
from typing import Union, Optional, Union, Dict, Any

# Third-party libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from geopy.distance import geodesic

from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict, RandomizedSearchCV
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    make_scorer,
)

import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

# %%
# --- MLflow Server ---
server_host = "127.0.0.1"
server_port = 8080
server_script_path = Path("../src/mlflow_server.py").resolve()
process_api = subprocess.Popen([sys.executable, str(server_script_path)])
print(f"MLflow server started with PID {process_api.pid}")
print(f"Access the MLflow UI at http://{server_host}:{server_port}")

# start tracking the server inititate in the terminal
mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")
# Out:
# MLflow server started with PID 18824
# Access the MLflow UI at http://127.0.0.1:8080

# %% [markdown]
# # EDA Part 1 - Understanding the Dataset

# %%
# importing the data
df = pd.read_csv(r'../data/raw/amazon_delivery.csv')
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# 0       Sunny    High   motorcycle           Urban             120
# 1      Stormy     Jam      scooter   Metropolitian             165
# 2  Sandstorms     Low   motorcycle           Urban             130
# 3       Sunny  Medium   motorcycle   Metropolitian             105
# 4      Cloudy    High      scooter   Metropolitian             150
#
#       Category
# 0     Clothing
# 1  Electronics
# 2       Sports
# 3    Cosmetics
# 4         Toys

# %%
# order_date, order_time and pickpu_time are string
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  object
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 5.3+ MB

# %%
# missing values already spotted
df.describe()
# Out:
#           Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# count  43739.000000  43685.000000    43739.000000     43739.000000
# mean      29.567137      4.633780       17.210960        70.661177
# std        5.815155      0.334716        7.764225        21.475005
# min       15.000000      1.000000      -30.902872       -88.366217
# 25%       25.000000      4.500000       12.933298        73.170283
# 50%       30.000000      4.700000       18.551440        75.898497
# 75%       35.000000      4.900000       22.732225        78.045359
# max       50.000000      6.000000       30.914057        88.433452
#
#        Drop_Latitude  Drop_Longitude  Delivery_Time
# count   43739.000000    43739.000000   43739.000000
# mean       17.459031       70.821842     124.905645
# std         7.342950       21.153148      51.915451
# min         0.010000        0.010000      10.000000
# 25%        12.985996       73.280000      90.000000
# 50%        18.633626       76.002574     125.000000
# 75%        22.785049       78.104095     160.000000
# max        31.054057       88.563452     270.000000

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Agent_Age           0
# Agent_Rating       54
# Store_Latitude      0
# Store_Longitude     0
# Drop_Latitude       0
# Drop_Longitude      0
# Order_Date          0
# Order_Time          0
# Pickup_Time         0
# Weather            91
# Traffic             0
# Vehicle             0
# Area                0
# Delivery_Time       0
# Category            0
# dtype: int64

# %%
# considering that there are NaN values and considering that they represent less than 1% of the table, the lines are going to be dropped
df = df.dropna()

# %%
# confirming that there are no NaN values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# order_date, order_time and pickup_time datatypes are wrong
# in order to solve this problem I wanna convert the 2 time columns to decimal and order date from string to datetime type
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

for col in ["Order_Time", "Pickup_Time"]:
    df[col] = pd.to_timedelta(df[col]).dt.total_seconds() / 3600

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43594 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43594 non-null  object
#  1   Agent_Age        43594 non-null  int64
#  2   Agent_Rating     43594 non-null  float64
#  3   Store_Latitude   43594 non-null  float64
#  4   Store_Longitude  43594 non-null  float64
#  5   Drop_Latitude    43594 non-null  float64
#  6   Drop_Longitude   43594 non-null  float64
#  7   Order_Date       43594 non-null  datetime64[ns]
#  8   Order_Time       43594 non-null  float64
#  9   Pickup_Time      43594 non-null  float64
#  10  Weather          43594 non-null  object
#  11  Traffic          43594 non-null  object
#  12  Vehicle          43594 non-null  object
#  13  Area             43594 non-null  object
#  14  Delivery_Time    43594 non-null  int64
#  15  Category         43594 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(6)
# memory usage: 5.7+ MB

# %%
# now we have 6 objects, 9 numeric e 1 datetime columns
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude Order_Date  Order_Time  Pickup_Time  \
# 0      22.765049       75.912471 2022-03-19       11.50    11.750000
# 1      13.043041       77.813237 2022-03-25       19.75    19.833333
# 2      12.924264       77.688400 2022-03-19        8.50     8.750000
# 3      11.053669       77.026494 2022-04-05       18.00    18.166667
# 4      13.012793       80.289982 2022-03-26       13.50    13.750000
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# 0       Sunny    High   motorcycle           Urban             120
# 1      Stormy     Jam      scooter   Metropolitian             165
# 2  Sandstorms     Low   motorcycle           Urban             130
# 3       Sunny  Medium   motorcycle   Metropolitian             105
# 4      Cloudy    High      scooter   Metropolitian             150
#
#       Category
# 0     Clothing
# 1  Electronics
# 2       Sports
# 3    Cosmetics
# 4         Toys

# %% [markdown]
# # EDA Part 2 - Understanding the Dataset

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Analysing object type

# %%
# profiler for object (string) columns
def profile_categorical_columns(df):
    """
    Generate a profile report for categorical columns in a DataFrame.

    Parameters
    ----------
    df : pandas.DataFrame
        The input DataFrame.

    Returns
    -------
    dict
        A dictionary where keys are column names and values are dictionaries
        containing:
            - 'unique_values': list of unique values in the column
            - 'unique_count': number of unique values
            - 'repeated_counts': value counts (only for values appearing more than once, sorted ascending)
    """
    categorical_columns = df.select_dtypes(include=["object"]).columns
    profile = {}

    for column in categorical_columns:
        uniques = df[column].unique().tolist()
        counts = df[column].value_counts()
        repeated_counts = counts[counts > 1].sort_values()

        profile[column] = {
            "unique_values": uniques,
            "unique_count": len(uniques),
            "repeated_counts": repeated_counts.to_dict(),
        }

    return profile

# %%
profile_categorical_columns(df)
# Out:
# {'Order_ID': {'unique_values': ['ialx566343618',
#    'akqg208421122',
#    'njpu434582536',
#    'rjto796129700',
#    'zguw716275638',
#    'fxuu788413734',
#    'njmo150975311',
#    'jvjc772545076',
#    'uaeb808891380',
#    'bgvc052754213',
#    'vmau710398846',
#    'lcwn330553507',
#    'wcjs752046999',
#    'blhl288691670',
#    'zyvo118176215',
#    'uhfs888375680',
#    'vmfv999642595',
#    'qfgc848777135',
#    'vwmc439983136',
#    'ntzy027061451',
#    'pbjm971961647',
#    'kjic578711491',
#    'rkzt648036688',
#    'segh259958026',
#    'owvs520891091',
#    'edrh271340988',
#    'qvfd540651807',
#    'gzfn634029300',
#    'xjps180812498',
#    'ahpg083217029',
#    'itii428784576',
#    'asis944862845',
#    'xzkg140273315',
#    'zotl583816092',
#    'agoo012263585',
#    'ezif478391605',
#    'tixw400453550',
#    'mrfx777445506',
#    'czjt755903822',
#    'zqtj827550147',
#    'luka250567007',
#    'zkat983341391',
#    'ydhu273019158',
#    'rpuq263118672',
#    'nvck471535045',
#    'rxgx102974679',
#    'ikas794013321',
#    'dsyl658069912',
#    'wzoc344425774',
#    'dwnh519656346',
#    'yakw330215137',
#    'dcdm719150402',
#    'fris321432357',
#    'mxuw713526914',
#    'carl449634661',
#    'msnw786727644',
#    'bbow373480117',
#    'vizd072469706',
#    'etss702593505',
#    'rxxx129114996',
#    'bull762076829',
#    'fpkv432118410',
#    'udpq945815554',
#    'qeqp930384577',
#    'cwvq091479872',
#    'ivtf765857546',
#    'emlt327861941',
#    'rufz727804632',
#    'gkrb550339468',
#    'tsec016509855',
#    'xczs106918282',
#    'lgee738117860',
#    'nxfs257449148',
#    'wycd588946822',
#    'bhdi726355812',
#    'wnbv620439671',
#    'jvco758418006',
#    'zkks967394571',
#    'oiyh656906407',
#    'dfit633531471',
#    'qhxw976953297',
#    'mryb985330207',
#    'jzam829230168',
#    'xnod694467359',
#    'hcno407153953',
#    'gyjc869072111',
#    'wkqq813752515',
#    'vdfj488526028',
#    'pngq326709686',
#    'caja224507886',
#    'hnme204254454',
#    'uehx759760979',
#    'sdod930462581',
#    'visy471360404',
#    'wddq796276216',
#    'pqya338067587',
#    'last796029882',
#    'mzyt873581742',
#    'kbhb286226770',
#    'okvp821614347',
#    'oska955853002',
#    'rgwl479077727',
#    'tmzv371880726',
#    'ofxt601212694',
#    'lbui872023073',
#    'ixfk439251990',
#    'njfz936670348',
#    'drir663128253',
#    'drdr957134932',
#    'qrzj427928057',
#    'hkit681446136',
#    'imnm972342448',
#    'wnne890905509',
#    'kbdc711046313',
#    'alem833315854',
#    'khjm619520065',
#    'oiay843077855',
#    'ohhc448549441',
#    'knul324217390',
#    'buux572471968',
#    'ieue797662723',
#    'eztk468187811',
#    'zzid436960558',
#    'kllk327072475',
#    'ubwl989345056',
#    'iimu721647260',
#    'tfxz025621580',
#    'kgjb145446786',
#    'xrxy085440961',
#    'pnzt689957903',
#    'qrng205617369',
#    'gycd207308146',
#    'wqfy256790455',
#    'vgjr167867003',
#    'jqco336937571',
#    'iwkp065421476',
#    'nwvu459529234',
#    'jjcl090851660',
#    'bpbi053158546',
#    'ksec432319879',
#    'rszv454658332',
#    'cdyc438548517',
#    'xoka811702118',
#    'nyum131271823',
#    'iwoy649851528',
#    'lhus187289759',
#    'szbb646301545',
#    'bwgn919229310',
#    'pdxn136638766',
#    'zzsx562940707',
#    'gyvm380029078',
#    'umwc109456087',
#    'dsbe906886027',
#    'xnzb532907287',
#    'ltrp525870768',
#    'rbzk606295253',
#    'ltoi660207512',
#    'pkhq469939766',
#    'jgbc287273591',
#    'xzzw562394658',
#    'gjwc226881646',
#    'lrbb564302256',
#    'fkyd365052251',
#    'wciq107093545',
#    'edxx482704762',
#    'jxsj508533395',
#    'xlta607070306',
#    'lubd358643567',
#    'ycwb227184501',
#    'mikp615052003',
#    'djrw974238657',
#    'rxki994339301',
#    'wfjy432968933',
#    'opdl820466364',
#    'wbpn330130607',
#    'jtsd466670552',
#    'enww399699472',
#    'rvns240114667',
#    'fvko144254933',
#    'jocn049365284',
#    'atgc248887447',
#    'jexa898688264',
#    'cmvs014428179',
#    'ntme294239634',
#    'tryr235168039',
#    'cpya420089193',
#    'opvd660426426',
#    'ecar963502319',
#    'pbmy587069805',
#    'wasv461278289',
#    'byhp076235734',
#    'ohfh963147472',
#    'nkmh560985800',
#    'gvea147758996',
#    'cypx969023715',
#    'oamt174420009',
#    'vmgc964372188',
#    'jnge623681084',
#    'kzvx918950241',
#    'rlgt572766152',
#    'lvnz878892159',
#    'zhyo265634674',
#    'ezxe128319748',
#    'kifq556800414',
#    'carl757119263',
#    'ywqd911535741',
#    'ppqt362000534',
#    'czis944259836',
#    'ibwr067523869',
#    'fyao616279169',
#    'bfvj522482572',
#    'zeaw181992534',
#    'tkua467465647',
#    'ljgp550489562',
#    'hnoc705310037',
#    'lzkv724137602',
#    'qpqb113436782',
#    'teij116088130',
#    'zutg690542042',
#    'qphf884454355',
#    'fcib257172141',
#    'fium151549195',
#    'vvnq162473052',
#    'hhem665543827',
#    'zfgf746938367',
#    'nfdj333236314',
#    'zfxe533340329',
#    'kwmv603335255',
#    'gopn683041817',
#    'ppri902151840',
#    'libi732501950',
#    'kdbu035077095',
#    'mfol662804540',
#    'bdgu970232668',
#    'odlo529484325',
#    'vxvr447893698',
#    'fmhd254099683',
#    'evzr452255970',
#    'hdgi344002220',
#    'ypdy132507323',
#    'vpun175942482',
#    'cdkz589624699',
#    'kiyg810534481',
#    'pwbi898606991',
#    'taqg748867597',
#    'dkgi875489081',
#    'ubag651976139',
#    'zxtz236128998',
#    'hmju318251956',
#    'ltwr528697521',
#    'jsku204560077',
#    'istj070213071',
#    'dahw022547497',
#    'vvgj958702360',
#    'rabu202619192',
#    'aeuj226729421',
#    'rbiv368919286',
#    'kxfb230420855',
#    'hwmm104541576',
#    'qnwk753395424',
#    'vvqg343205052',
#    'iuxj806937978',
#    'yyny933118563',
#    'bwhs416644198',
#    'rfxd157515921',
#    'pgjt711137922',
#    'fxir538138707',
#    'kezq280741564',
#    'dqha770938362',
#    'biau131098726',
#    'zkun393659280',
#    'lxwa140818117',
#    'uyid942578627',
#    'scqu849553683',
#    'mctx146223837',
#    'cyko979976221',
#    'uesw387337499',
#    'wowz415217997',
#    'uxsb403561931',
#    'cyye995820696',
#    'jbts229431770',
#    'iqbd216667101',
#    'bszz787750715',
#    'eynm000731182',
#    'cdmn013747827',
#    'fxuz549696901',
#    'jtpt648811611',
#    'oxji736034406',
#    'rihr033620085',
#    'gczg917526696',
#    'svpx912240732',
#    'asgd164341326',
#    'xqcr834027606',
#    'dmrl564554163',
#    'efrs776811164',
#    'ljep947754095',
#    'ljfy543933323',
#    'fshk983313794',
#    'wypw496102732',
#    'ayns342721271',
#    'thym058259757',
#    'lgzn457957462',
#    'qezt047211927',
#    'gzdo509306528',
#    'ersz046238543',
#    'tgpw108094548',
#    'inqt227293158',
#    'mwyi621708115',
#    'hzpx007931304',
#    'gbab110045112',
#    'hvpj165495397',
#    'ceed295586354',
#    'tonn051257985',
#    'erap841821582',
#    'iavt937545530',
#    'trka856987401',
#    'lcgk008504983',
#    'zqro449286965',
#    'syeh579470089',
#    'zhab316861798',
#    'qqjl805129936',
#    'weco669309017',
#    'zbel647135442',
#    'emwe467794784',
#    'xznm347660092',
#    'nyfh224947388',
#    'uvri048682496',
#    'bbws342212288',
#    'wsoh266827723',
#    'leff787822709',
#    'talu198958493',
#    'anfx475383342',
#    'eddt314765083',
#    'pcyt916802893',
#    'ungk686699285',
#    'jgcy113446649',
#    'ronf620294989',
#    'hoxq128553542',
#    'pmtg425435413',
#    'qefg170628671',
#    'bdlk287272047',
#    'iqem237229463',
#    'zazf712069296',
#    'dpcr770207794',
#    'glsd963477325',
#    'zhhx122382345',
#    'titu043025048',
#    'gyxe336866683',
#    'zlcm795242431',
#    'zdvi265864937',
#    'wduj099075306',
#    'xhwj851689395',
#    'opbb084664115',
#    'nplz786278633',
#    'vfml243571298',
#    'evto530786855',
#    'ckgu502252849',
#    'tjxh038296843',
#    'xhlz301038990',
#    'zpnu794398600',
#    'xiuy990187238',
#    'mupr233190762',
#    'pkqs694908430',
#    'qibd572188244',
#    'rwkg752700186',
#    'xukr152686247',
#    'pkts252955495',
#    'kjef892715538',
#    'pmpr684370621',
#    'bpyt851249485',
#    'fdjp742606171',
#    'deff957321361',
#    'vakz912181469',
#    'lxlx275255455',
#    'dowq522268038',
#    'xdao434795901',
#    'qzve473103395',
#    'sgrh968289641',
#    'jpet729617185',
#    'tbbu562785662',
#    'yhct639146328',
#    'vpzi082179640',
#    'wxqg297592780',
#    'eein393878639',
#    'qkiq165480717',
#    'hqwk443892657',
#    'xkxm865630486',
#    'bvni933228891',
#    'befv867092423',
#    'hobf254746878',
#    'lhfo186255622',
#    'emki208355100',
#    'eiug703797186',
#    'gpgw045112006',
#    'pajv540287866',
#    'pfch546197063',
#    'watp349944722',
#    'ipvd026583007',
#    'pexn467185751',
#    'nmla539707523',
#    'dbuw981669021',
#    'dbyg819334603',
#    'koew144021127',
#    'qmjh777621315',
#    'pszf462397050',
#    'figc612141073',
#    'gpwj834408989',
#    'pwbf401580256',
#    'vpzj106843126',
#    'rpxi920665792',
#    'vhkj347911892',
#    'ilfo183800165',
#    'blgx713939207',
#    'wlra252926669',
#    'vxra135801103',
#    'fzng561300776',
#    'sdij345774967',
#    'ylyn963444268',
#    'prwc675910621',
#    'sqjm123634300',
#    'bptj463968079',
#    'njei617905873',
#    'nltq801700453',
#    'jttm849299889',
#    'dmps249322564',
#    'gego068198063',
#    'fptn470372741',
#    'gqbu367833799',
#    'izaj168715864',
#    'fnep523025583',
#    'prmd574549289',
#    'mrjm925736117',
#    'bxmi331655934',
#    'mhbw191834924',
#    'zgus506380717',
#    'qebb550457670',
#    'nkwa401940966',
#    'cywj467789158',
#    'sjkg905066419',
#    'xntp740548398',
#    'pvcu885016852',
#    'xzhm898208742',
#    'uglc908112005',
#    'ggni863426619',
#    'bzru027859331',
#    'abfq998863769',
#    'wywl453950288',
#    'dypb040671273',
#    'vqlk306910270',
#    'hvgr961766492',
#    'lmam222460100',
#    'ynfp918283334',
#    'ntqf654847526',
#    'wltg948769753',
#    'wfnp526037482',
#    'snnk405400637',
#    'wpqb321718229',
#    'sdoi829127570',
#    'idya109511672',
#    'ttrz409682533',
#    'nfya937262694',
#    'lmop404805897',
#    'ybxm786583586',
#    'enld417016844',
#    'lmmw269814056',
#    'iwhg780258471',
#    'iwgk345795951',
#    'tsgt870627135',
#    'iceq731335361',
#    'xiqr562543389',
#    'ccvj862813862',
#    'vavf041518880',
#    'ojgk976611501',
#    'gzhs999389838',
#    'lpoo559278752',
#    'ciiu227813992',
#    'dmfn307541025',
#    'whbe278371630',
#    'ajon496915803',
#    'fjwn048296205',
#    'hibb670568838',
#    'mpxz628633412',
#    'rqqt145827294',
#    'xrou628500081',
#    'xnwm549054246',
#    'tcjj860782373',
#    'ceoa860679195',
#    'ozff337964990',
#    'hdrw273058143',
#    'jjpc681328627',
#    'wnja265203362',
#    'kkkn806065019',
#    'ahcl676711139',
#    'fnmz024487519',
#    'tsnh426803977',
#    'jlvk970569104',
#    'nkob102431367',
#    'aitb076913492',
#    'zzht454845366',
#    'penp730595480',
#    'tqqq117400105',
#    'wrbr570700916',
#    'wzvs619072447',
#    'oini183602327',
#    'elrp114539975',
#    'fvoq332072223',
#    'kemd906602818',
#    'kqmi499374214',
#    'qdqs225203666',
#    'ztel491150706',
#    'sfok287655638',
#    'rbvw350017323',
#    'evfg719847858',
#    'kcdr224504524',
#    'nuxp187566978',
#    'ervj934596417',
#    'kqnb541413741',
#    'oric826953147',
#    'urec609350393',
#    'ovti492712870',
#    'brfo817641389',
#    'pbsp176319059',
#    'kfjw636000221',
#    'szso398384860',
#    'pjbh964684827',
#    'oaew463729559',
#    'dhru296264034',
#    'jrdt044319812',
#    'aefs889604846',
#    'aozl672518026',
#    'fmmu732691037',
#    'cmnr733682904',
#    'velf920731059',
#    'grsq278292648',
#    'rqha328591539',
#    'rhpv487359562',
#    'aokn153705465',
#    'tnxr721054246',
#    'sxnc962329653',
#    'hsbp920939915',
#    'mbhl763139783',
#    'dqml870257443',
#    'oipo304682095',
#    'npqc426335347',
#    'kbcb187418479',
#    'nvss305715416',
#    'nfbo612860913',
#    'bvje827756058',
#    'tmra080782884',
#    'gtmc763426867',
#    'kjln790080169',
#    'gqyt412008922',
#    'hojh303673874',
#    'uowo219202183',
#    'laly052364040',
#    'seue774035229',
#    'hpfx282951824',
#    'kwac459258247',
#    'drnq455410643',
#    'cpai239579459',
#    'vjqj497482999',
#    'ikqm848453901',
#    'escq078763525',
#    'llgk631278832',
#    'qpgp954149325',
#    'qhmc638167529',
#    'qthn147451965',
#    'sfpc015585430',
#    'hllu627872258',
#    'wrjr749227681',
#    'xzrl716784548',
#    'mmbt765343357',
#    'zayq005312106',
#    'icjn893090853',
#    'jwef100439998',
#    'iray690328025',
#    'kdbz058571456',
#    'qbnx455660626',
#    'eibc335635387',
#    'kxcm483694128',
#    'lyqs160626048',
#    'sqpt381009382',
#    'kzec642267375',
#    'fjsy457667101',
#    'qcyn693653025',
#    'zxza102160001',
#    'xdus014073429',
#    'kdoi450584961',
#    'ikkh818371440',
#    'nqfm352762141',
#    'jhfa779664836',
#    'xbxn200447293',
#    'necv303251571',
#    'wqea232651451',
#    'zhbv507383833',
#    'vlst254301121',
#    'kklz242189792',
#    'xcpn200806737',
#    'dxuq411671723',
#    'dlxs382799710',
#    'ltpv954472394',
#    'oitk739579230',
#    'pazq694586181',
#    'oisq612742703',
#    'wzvu432262336',
#    'wper150449859',
#    'xzho220714716',
#    'zrwp620728072',
#    'gyxw898561903',
#    'ecem060800309',
#    'botn800344578',
#    'tqxi045146775',
#    'kgap585195507',
#    'dmfj519519219',
#    'tjib241378229',
#    'cads491909704',
#    'yoxg386579172',
#    'jgze646200858',
#    'ugdy034169362',
#    'xzbl323280136',
#    'lqyq813452304',
#    'pchy611585669',
#    'okgr359664734',
#    'wzel129960984',
#    'fhco827148157',
#    'bcww473893145',
#    'azgk940712115',
#    'bzoo769001078',
#    'ubcd783242087',
#    'jiyc198145687',
#    'kscw878662353',
#    'kvqk488778566',
#    'kpjr226562494',
#    'igvi130716526',
#    'fkun064220230',
#    'lyyj446897623',
#    'vdsc242802639',
#    'ittj864611306',
#    'jzzk349096295',
#    'sdxs740704107',
#    'mttu695236585',
#    'ooki837835398',
#    'yogd343858268',
#    'gcvw047760888',
#    'jrpn294896376',
#    'urgh719421847',
#    'xwtx438995455',
#    'sccp018255873',
#    'xxor408538921',
#    'jrzw710510668',
#    'eggk782414616',
#    'hidy261467651',
#    'jptb980554885',
#    'vpsf780953121',
#    'yzbx667733486',
#    'hxog930219425',
#    'jkkv014691736',
#    'sfrj659517575',
#    'onok376892035',
#    'xnmd060157935',
#    'mzeb245970250',
#    'nuyk105990581',
#    'qodg716991505',
#    'cvog500284478',
#    'jwdp033586938',
#    'ggxk185781605',
#    'jysr427028144',
#    'apll985655975',
#    'ybmg115603702',
#    'hgvp189522861',
#    'wjsm256325267',
#    'mirt199087171',
#    'wigz116241077',
#    'djni578384701',
#    'booz176813299',
#    'yrxv783282166',
#    'mjzv475761405',
#    'vogj512177127',
#    'vmcr655255820',
#    'sbaj018996229',
#    'mivz461407242',
#    'rdus129341681',
#    'fump208124017',
#    'zzdt398224350',
#    'rosu742347769',
#    'mltg533186640',
#    'griq568538346',
#    'ulic859633079',
#    'hikf286518789',
#    'izvl399117454',
#    'tbln574225506',
#    'sgep605324393',
#    'sgrv807655331',
#    'ltuo081712610',
#    'xbhq884931942',
#    'nymu234606643',
#    'qnht214154545',
#    'itfi259801851',
#    'vhkd487067380',
#    'kbln393702128',
#    'kjni870891929',
#    'ognp232305886',
#    'guht709314264',
#    'vazf926651495',
#    'gwsn039100496',
#    'fvvr839976631',
#    'hvcw149352257',
#    'nsor575698541',
#    'noiv975543322',
#    'axtz155758687',
#    'cqkf340722182',
#    'uzno711040707',
#    'yucd410527852',
#    'hnhg555883986',
#    'larg251421075',
#    'mqhw773310802',
#    'znys264264304',
#    'jbvi392181477',
#    'hamx365036358',
#    'euea467890264',
#    'fyhn937992389',
#    'brjp572494933',
#    'ywqt342960968',
#    'oifg249484577',
#    'amwt677706239',
#    'bvka348874203',
#    'xncp919063413',
#    'dzja169620854',
#    'mfkm295992455',
#    'kljo727155219',
#    'crwj681968834',
#    'xigp305225329',
#    'orkh922812379',
#    'epws628648070',
#    'vjso332723361',
#    'bncl161561536',
#    'phdn272715324',
#    'sojs277662991',
#    'plbh544658611',
#    'dwpz461110458',
#    'iegb214834761',
#    'ocwa633756358',
#    'xxku620056780',
#    'vkzz832219130',
#    'ohzf165095441',
#    'wafx978606463',
#    'mjny778475225',
#    'lfkr680811422',
#    'fakz515425358',
#    'intd941914908',
#    'mmnq033985559',
#    'egyg586560007',
#    'tsjg989601604',
#    'dyyv405381763',
#    'ypoi593771415',
#    'iwqj434088008',
#    'gvoc220746028',
#    'owjw109017720',
#    'wnua569339256',
#    'rkkn946013798',
#    'sedz438633697',
#    'phvu276201595',
#    'yzco846093054',
#    'kbxz166579673',
#    'jsvc767291402',
#    'rbfe187517457',
#    'bsrk558755933',
#    'dgye215214408',
#    'eyhx467155501',
#    'cpvr765393098',
#    'jrzz070590798',
#    'wpvn370540505',
#    'tifw976395462',
#    'icti836263169',
#    'kddb655628516',
#    'vnhq327619759',
#    'npch760309383',
#    'evvs500014087',
#    'tech899419111',
#    'gtvm381235972',
#    'omzj432297634',
#    'essy604523183',
#    'cusu248875311',
#    'edco522391392',
#    'ctoj872363102',
#    'taqs429293566',
#    'vqty702282323',
#    'rpge560994264',
#    'rqcs923125271',
#    'bkmx082772212',
#    'cfhn315113890',
#    'adiv498964791',
#    'hojv987068372',
#    'zvkx405674622',
#    'fgzk425074716',
#    'paom510411686',
#    'nung093192090',
#    'fwvo451250409',
#    'awyc243905733',
#    'unic591472044',
#    'nhdk983966912',
#    'kgbi202766353',
#    'rxrk922214537',
#    'iauj712732773',
#    'itdi360890843',
#    'ziyc225083622',
#    'cuql549797849',
#    'uihw861416295',
#    'cmqf429277404',
#    'iypw167065359',
#    'aecv597151350',
#    'addp276655174',
#    'jvev469820141',
#    'twuy336541938',
#    'uotq333364336',
#    'opdf699695945',
#    'vwml283310596',
#    'jlwh564514757',
#    'fdng780283298',
#    'rmle339606284',
#    'fokf045562405',
#    'mmhe959868409',
#    'rzbq717508778',
#    'pgae607790008',
#    'hpua184773788',
#    'gggb753628772',
#    'yskx271672040',
#    'vwhm385500781',
#    'agux910512982',
#    'jume050100672',
#    'mafw581032294',
#    'nrmz910220511',
#    'goym112724831',
#    'mcjg202506760',
#    'gvjx942268592',
#    'oosb954281783',
#    'msst937092386',
#    'yarl392103492',
#    'trvz490719836',
#    'kwvo176250144',
#    'wjky761986350',
#    'rleh153953902',
#    'vcpo904984519',
#    'qith021312304',
#    'yxel261089528',
#    'whjk646058031',
#    'svxy111176694',
#    'pqlj119874486',
#    'gsjz313680509',
#    'ysof955290928',
#    'hzir281026902',
#    'lezb158488142',
#    'ters101342796',
#    'osuu217847532',
#    'uybm390303163',
#    'tpma104105121',
#    'bebv151631351',
#    'eqko291188915',
#    'bpkr573708864',
#    'tiku670163066',
#    'gcjo049307092',
#    'wdiy581729479',
#    'npwo106548418',
#    'ytvd567194993',
#    'lcma897382130',
#    'prsx065636625',
#    'smtn937032095',
#    'ozjz810226690',
#    'gasz878984846',
#    'doai643866562',
#    'xqes087347664',
#    'bjdg509711656',
#    'clet305799189',
#    'ojkf639678702',
#    'ovzn802438564',
#    'xnsg076844692',
#    'elcp839245372',
#    'lvph411101254',
#    'urnq808828173',
#    'kxdc810247309',
#    'ydsr554309330',
#    'wmds295023114',
#    'snxt657345988',
#    'tlpw634103887',
#    'hxlc252959441',
#    'qfnw066693562',
#    'dxgf368981190',
#    'saaz395276267',
#    'mjjl405462834',
#    'eciz076285667',
#    'hpap861728738',
#    'ckgk578696273',
#    'mxpd911239648',
#    'bfup174692326',
#    'bkpw908369288',
#    'jvxn936557952',
#    'qadk676361128',
#    'rbxp135564227',
#    'nilz831017646',
#    'znzw919146964',
#    'nhda436221842',
#    'rhqv232160757',
#    'dzcs575936167',
#    'aazb527937675',
#    'evzc748467090',
#    'jpzg430807944',
#    'dvmq392406893',
#    'tnkl744303420',
#    'lifh604608424',
#    'scbx441036149',
#    'gtzj875717503',
#    'wbjr032258806',
#    'caty508037770',
#    'kchf265636656',
#    'etrv648439532',
#    'dgry532903313',
#    'mpkj907688327',
#    'hitb222861066',
#    'zbwm782393236',
#    'kmbo231089374',
#    'untf875440546',
#    'mkva994791983',
#    'hprk377013710',
#    'prlz497875409',
#    'dcyv640821977',
#    'tnte563080527',
#    'pgzl777716873',
#    'uqac946966795',
#    'srts927270263',
#    'qcbh914401278',
#    'ontn116289809',
#    'heke604150121',
#    'mleb942163074',
#    'obhg842862910',
#    'zpor766267650',
#    'rxfg748489108',
#    'ifzh038597668',
#    'vwne871291890',
#    'nvkv892242670',
#    'tfpw264934804',
#    'rmgo277916637',
#    'rjuk855079528',
#    'sbwi574419008',
#    'opms922781586',
#    'ivpy820825330',
#    'hdce688458513',
#    'gxan859732316',
#    'kzbu064137694',
#    'ugxo576067618',
#    'bnva693926602',
#    'pnrw431937733',
#    'xhqi749945004',
#    'bnnr851834947',
#    'tgte845838682',
#    'rndx903920678',
#    'woyb459293049',
#    'wsri799484644',
#    'exyc683633861',
#    'oels853255874',
#    'brnd208997655',
#    'kfhd623107769',
#    'nzhp394170773',
#    'extd941092460',
#    'ppqi698287741',
#    'ftxu257921170',
#    'ohfz488690337',
#    'hjje440881295',
#    'zqcy759656108',
#    'ucak745030472',
#    'dxtj319166247',
#    'kitt337907719',
#    'dvkw198193286',
#    'xqkm789529983',
#    'uxnt196160734',
#    'hgqd672005050',
#    'nrgt655064427',
#    'pign307670486',
#    'cmiy697846170',
#    'svlw573443641',
#    'wkyn138619655',
#    'pdpv628261886',
#    'ebtw655648192',
#    'hqju352058882',
#    'rvxp980815851',
#    'wzmv373637225',
#    'eamn881338159',
#    'huhy242117286',
#    'gwnt537190370',
#    'spqt033970808',
#    'qsyq438659561',
#    'bxmp908266441',
#    'qkwq310213954',
#    'xpdx531588871',
#    'oolu940481971',
#    'drgh498946193',
#    'mtcr221173183',
#    'ncnc584203263',
#    'aeuz262262868',
#    'ewye976989972',
#    'kqub936334770',
#    ...],
#   'unique_count': 43594,
#   'repeated_counts': {}},
#  'Weather': {'unique_values': ['Sunny',
#    'Stormy',
#    'Sandstorms',
#    'Cloudy',
#    'Fog',
#    'Windy'],
#   'unique_count': 6,
#   'repeated_counts': {'Sunny': 7067,
#    'Windy': 7211,
#    'Sandstorms': 7238,
#    'Cloudy': 7277,
#    'Stormy': 7366,
#    'Fog': 7435}},
#  'Traffic': {'unique_values': ['High ', 'Jam ', 'Low ', 'Medium '],
#   'unique_count': 4,
#   'repeated_counts': {'High ': 4294,
#    'Medium ': 10614,
#    'Jam ': 13710,
#    'Low ': 14976}},
#  'Vehicle': {'unique_values': ['motorcycle ', 'scooter ', 'van'],
#   'unique_count': 3,
#   'repeated_counts': {'van': 3518, 'scooter ': 14590, 'motorcycle ': 25486}},
#  'Area': {'unique_values': ['Urban ',
#    'Metropolitian ',
#    'Semi-Urban ',
#    'Other'],
#   'unique_count': 4,
#   'repeated_counts': {'Semi-Urban ': 152,
#    'Other': 1135,
#    'Urban ': 9715,
#    'Metropolitian ': 32592}},
#  'Category': {'unique_values': ['Clothing',
#    'Electronics',
#    'Sports',
#    'Cosmetics',
#    'Toys',
#    'Snacks',
#    'Shoes',
#    'Apparel',
#    'Jewelry',
#    'Outdoors',
#    'Grocery',
#    'Books',
#    'Kitchen',
#    'Home',
#    'Pet Supplies',
#    'Skincare'],
#   'unique_count': 16,
#   'repeated_counts': {'Shoes': 2655,
#    'Clothing': 2657,
#    'Kitchen': 2663,
#    'Cosmetics': 2666,
#    'Home': 2678,
#    'Pet Supplies': 2679,
#    'Grocery': 2687,
#    'Sports': 2708,
#    'Apparel': 2718,
#    'Outdoors': 2739,
#    'Snacks': 2762,
#    'Skincare': 2764,
#    'Toys': 2771,
#    'Jewelry': 2793,
#    'Books': 2813,
#    'Electronics': 2841}}}

# %% [markdown]
# #### Critical Points
# * Traffic: “High” = 4294, “Low” = 14976 → significant imbalance (~3.5x).
# * Vehicle: “van” = 3518, “motorcycle” = 25486 → notable imbalance (~7x).
# * Area: “Semi-Urban” = 152, “Metropolitian” = 32592 → extreme imbalance (~215x).
# * Impact: These columns can bias ML models or statistical analyses; consider resampling, grouping categories, or weighting.

# %% [markdown]
# #### Treating Objects
# * Only numbers are understood by ML models

# %%
# visualizing the object datatype columns
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Order_ID', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Category'], dtype='object')

# %%
df['Order_ID']
# Out:
# 0        ialx566343618
# 1        akqg208421122
# 2        njpu434582536
# 3        rjto796129700
# 4        zguw716275638
#              ...
# 43734    jlxf819993117
# 43735    aevx342135787
# 43736    xnek760674819
# 43737    cynl434665991
# 43738    nsyz997960170
# Name: Order_ID, Length: 43594, dtype: object

# %%
# the Order_ID column won't be considered because it's not a feature itself.
df = df.drop(columns='Order_ID')
df.columns
# Out:
# Index(['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
#        'Drop_Latitude', 'Drop_Longitude', 'Order_Date', 'Order_Time',
#        'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
#        'Category'],
#       dtype='object')

# %%
# encoding categorical values
def encode_categorical_columns(df, output_dir="../data/processed/mappings"):
    """
    Encode categorical (object) columns in a DataFrame using OrdinalEncoder.
    For each processed column, saves a CSV mapping between categories and encoded values.

    Parameters
    ----------
    df : pandas.DataFrame
        Input DataFrame with categorical columns to encode.
    output_dir : str or Path, default "../data/processed/mappings"
        Directory where CSV mapping files will be saved.

    Returns
    -------
    pandas.DataFrame
        DataFrame with categorical columns encoded as numeric.
    dict
        Dictionary containing category mappings for each column.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    df_encoded = df.copy()
    mappings = {}

    categorical_columns = df.select_dtypes(include=["object"]).columns

    for column in categorical_columns:
        if df[column].notna().sum() == 0:
            continue

        encoder = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
        encoded_values = encoder.fit_transform(df[[column]])

        df_encoded[column] = pd.Series(encoded_values.ravel(), dtype="Int64")
        mappings[column] = dict(enumerate(encoder.categories_[0]))

        mapping_df = pd.DataFrame(
            {"index": range(len(encoder.categories_[0])), "category": encoder.categories_[0]}
        )
        mapping_df.to_csv(output_dir / f"{column}_mapping.csv", index=False)

    return df_encoded, mappings

# %%
# Apply the encoding function
df_encoded, encoders_dict = encode_categorical_columns(df)
df_encoded.to_csv(r'../data/processed/dataframe_encoded.csv') # saving the table
df_encoded.head()
# Out:
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  Drop_Latitude  \
# 0         37           4.9       22.745049        75.892471      22.765049
# 1         34           4.5       12.913041        77.683237      13.043041
# 2         23           4.4       12.914264        77.678400      12.924264
# 3         38           4.7       11.003669        76.976494      11.053669
# 4         32           4.6       12.972793        80.249982      13.012793
#
#    Drop_Longitude Order_Date  Order_Time  Pickup_Time  Weather  Traffic  \
# 0       75.912471 2022-03-19       11.50    11.750000        4        0
# 1       77.813237 2022-03-25       19.75    19.833333        3        1
# 2       77.688400 2022-03-19        8.50     8.750000        2        2
# 3       77.026494 2022-04-05       18.00    18.166667        4        3
# 4       80.289982 2022-03-26       13.50    13.750000        0        0
#
#    Vehicle  Area  Delivery_Time  Category
# 0        0     3            120         2
# 1        1     0            165         4
# 2        0     3            130        14
# 3        0     0            105         3
# 4        1     0            150        15

# %% [markdown]
# ### Analysing numeric type

# %%
# functions to analyse the numeric type columns
def detect_outliers_iqr(series, factor=1.5):
    """
    Detect outliers in a numeric Series using the Interquartile Range (IQR) method.

    Parameters
    ----------
    series : pandas.Series
        Numeric data.
    factor : float, default 1.5
        The multiplier for the IQR to define outlier thresholds.

    Returns
    -------
    pandas.Series
        Subset of the original Series containing only the outlier values.
    """
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - factor * iqr
    upper_bound = q3 + factor * iqr

    return series[(series < lower_bound) | (series > upper_bound)]


def profile_numeric_columns(df):
    """
    Generate a compact profile analysis of numerical columns in a DataFrame.
    Focuses on variability, skewness, outliers, and uniqueness.

    Parameters
    ----------
    df : pandas.DataFrame
        Input DataFrame.

    Returns
    -------
    pandas.DataFrame
        DataFrame where each row corresponds to a numeric column and contains:
            - mean
            - std
            - skewness
            - outliers_count
            - unique_count
            - unique_pct
            - value_range
    """
    numeric_columns = df.select_dtypes(include=[np.number]).columns
    profile_records = []

    for col in numeric_columns:
        series = df[col].dropna()
        outliers = detect_outliers_iqr(series)

        profile_records.append({
            "column": col,
            "mean": series.mean(),
            "std": series.std(),
            "skewness": series.skew(),
            "outliers_count": len(outliers),
            "unique_count": series.nunique(),
            "unique_pct": (series.nunique() / len(series)) * 100 if len(series) > 0 else 0,
            "value_range": series.max() - series.min(),
        })

    return pd.DataFrame(profile_records).set_index("column")

# %%
numeric_analysis = profile_numeric_columns(df)
numeric_analysis.to_csv(r'../data/processed/profile_analyser_numeric_columns.csv') # saving the table
numeric_analysis
# Out:
#                        mean        std  skewness  outliers_count  \
# column
# Agent_Age         29.555719   5.760689 -0.014471               0
# Agent_Rating       4.635287   0.313827 -1.793118            1132
# Store_Latitude    17.244769   7.690005 -1.055690             151
# Store_Longitude   70.768898  21.128773 -2.954381            4301
# Drop_Latitude     17.461540   7.338199 -0.700486               0
# Drop_Longitude    70.832489  21.128940 -2.954371            6468
# Order_Time        17.917196   4.841461 -1.046237             429
# Pickup_Time       17.629523   5.358668 -1.263466            1254
# Delivery_Time    124.916433  51.941975  0.188318              79
#
#                  unique_count  unique_pct  value_range
# column
# Agent_Age                  20    0.045878    19.000000
# Agent_Rating               26    0.059641     2.500000
# Store_Latitude            489    1.121714    61.816929
# Store_Longitude           389    0.892325    88.433452
# Drop_Latitude            4365   10.012846    31.044057
# Drop_Longitude           4365   10.012846    88.553452
# Order_Time                176    0.403725    23.916667
# Pickup_Time               193    0.442721    23.916667
# Delivery_Time              89    0.204157   260.000000

# %% [markdown]
# #### Critical Points
#
#
# Agent_Age: discard → 0% variability, provides no useful information.
#
# Agent_Rating: discard or investigate → almost constant (0.1% variability), many outliers (1132) and negative skew; concentrated at high values – consider converting into categories.
#
# Order_Time: transform into derived features (hour of day, shift, delay) → low variability (0.4%), negative skew (-1.05) and 429 outliers; raw values not useful.
#
# Pickup_Time: transform into derived features (waiting time, delay) → low variability (0.4%), negative skew (-1.26) and 1254 outliers; raw values not useful.
#
# Delivery_Time: transform into performance feature (delivery time) → low variability (0.2%) and 79 outliers; outliers may represent critical deliveries.

# %% [markdown]
# ## Multivariate Analysis - Correlations

# %%
# recheking the count, null and datatypes
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43594 entries, 0 to 43738
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Agent_Age        43594 non-null  int64
#  1   Agent_Rating     43594 non-null  float64
#  2   Store_Latitude   43594 non-null  float64
#  3   Store_Longitude  43594 non-null  float64
#  4   Drop_Latitude    43594 non-null  float64
#  5   Drop_Longitude   43594 non-null  float64
#  6   Order_Date       43594 non-null  datetime64[ns]
#  7   Order_Time       43594 non-null  float64
#  8   Pickup_Time      43594 non-null  float64
#  9   Weather          43449 non-null  Int64
#  10  Traffic          43449 non-null  Int64
#  11  Vehicle          43449 non-null  Int64
#  12  Area             43449 non-null  Int64
#  13  Delivery_Time    43594 non-null  int64
#  14  Category         43449 non-null  Int64
# dtypes: Int64(5), datetime64[ns](1), float64(7), int64(2)
# memory usage: 5.5 MB

# %%
df_encoded.columns
# Out:
# Index(['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
#        'Drop_Latitude', 'Drop_Longitude', 'Order_Date', 'Order_Time',
#        'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
#        'Category'],
#       dtype='object')

# %%
# table for correlation
df_for_corr = df_encoded[['Agent_Age', 'Agent_Rating', 'Order_Date', 'Order_Time',
       'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
       'Category']] # latitude and longitude removed
correlation_matrix = df_for_corr.corr()

# %% [markdown]
# #### Correlation Matrix

# %%
# Set global style for seaborn
sns.set_theme(style="whitegrid")

# Create mask for upper triangle
upper_triangle_mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Create the heatmap
fig, ax = plt.subplots(figsize=(12, 10))

sns.heatmap(
    correlation_matrix,
    mask=upper_triangle_mask,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    center=0,
    square=True,
    cbar_kws={"label": "Correlation Coefficient"},
    annot_kws={"size": 10, "weight": "bold"},
    ax=ax,
)

ax.set_title(
    "Feature Correlation Matrix\nDelivery Dataset Analysis",
    fontsize=16,
    fontweight="bold",
    pad=20,
)
ax.set_xlabel("Features", fontsize=12, fontweight="bold")
ax.set_ylabel("Features", fontsize=12, fontweight="bold")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Distance feature

# %%
df.columns
# Out:
# Index(['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
#        'Drop_Latitude', 'Drop_Longitude', 'Order_Date', 'Order_Time',
#        'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
#        'Category'],
#       dtype='object')

# %%
def calculate_geodesic_distance(lat1, lon1, lat2, lon2):
    """
    Calculate geodesic distance between two geographic coordinates.

    Parameters
    ----------
    lat1, lon1 : float
        Latitude and longitude of the first point.
    lat2, lon2 : float
        Latitude and longitude of the second point.

    Returns
    -------
    float
        Distance in kilometers between the two points.
    """
    return geodesic((lat1, lon1), (lat2, lon2)).kilometers

# %%
df["distance_km"] = df.apply(
    lambda row: calculate_geodesic_distance(
        row["Store_Latitude"],
        row["Store_Longitude"],
        row["Drop_Latitude"],
        row["Drop_Longitude"],
    ),
    axis=1,
)

# %%
df_encoded = df_encoded.drop(columns=['Store_Latitude', 'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude'])
df_encoded.to_csv(r'../data/processed/dataframe_encoded_distance.csv') # saving the table
df_encoded.head()
# Out:
#    Agent_Age  Agent_Rating Order_Date  Order_Time  Pickup_Time  Weather  \
# 0         37           4.9 2022-03-19       11.50    11.750000        4
# 1         34           4.5 2022-03-25       19.75    19.833333        3
# 2         23           4.4 2022-03-19        8.50     8.750000        2
# 3         38           4.7 2022-04-05       18.00    18.166667        4
# 4         32           4.6 2022-03-26       13.50    13.750000        0
#
#    Traffic  Vehicle  Area  Delivery_Time  Category
# 0        0        0     3            120         2
# 1        1        1     0            165         4
# 2        2        0     3            130        14
# 3        3        0     0            105         3
# 4        0        1     0            150        15

# %% [markdown]
# ## Time features

# %%
def create_time_features(df, drop_original=True):
    """
    Create time-based features for delivery prediction.

    Features created:
    -----------------
    - wait_time (float): Time difference between order and pickup in minutes
    - order_hour (int): Hour of the order
    - pickup_hour (int): Hour of the pickup
    - day_of_week (int): Day of the week (0=Monday, 6=Sunday)
    - is_weekend (int): 1 if Saturday or Sunday, 0 otherwise

    Parameters
    ----------
    df : pandas.DataFrame
        Input DataFrame. Must contain columns 'Order_Date' and 'Pickup_Time'.
    drop_original : bool, default=True
        Whether to drop the original datetime columns after feature creation.

    Returns
    -------
    pandas.DataFrame
        Copy of the DataFrame with new features added (and optionally
        original datetime columns removed).
    """
    df = df.copy()

    # Convert to datetime
    df["Order_Date"] = pd.to_datetime(df["Order_Date"])
    df["Pickup_Time"] = pd.to_datetime(df["Pickup_Time"])

    # Create features
    df["wait_time"] = (df["Pickup_Time"] - df["Order_Date"]).dt.total_seconds() / 60
    df["order_hour"] = df["Order_Date"].dt.hour
    df["pickup_hour"] = df["Pickup_Time"].dt.hour
    df["day_of_week"] = df["Order_Date"].dt.dayofweek
    df["is_weekend"] = df["day_of_week"].isin([5, 6]).astype(int)

    if drop_original:
        df = df.drop(columns=["Order_Date", "Pickup_Time"])

    return df

# %%
df_final = create_time_features(df_encoded)
df_final.to_csv(r'../data/processed/dataframe_final.csv') # saving the table
df_final
# Out:
#        Agent_Age  Agent_Rating  Order_Time  Weather  Traffic  Vehicle  Area  \
# 0             37           4.9   11.500000        4        0        0     3
# 1             34           4.5   19.750000        3        1        1     0
# 2             23           4.4    8.500000        2        2        0     3
# 3             38           4.7   18.000000        4        3        0     0
# 4             32           4.6   13.500000        0        0        1     0
# ...          ...           ...         ...      ...      ...      ...   ...
# 43734         30           4.8   11.583333     <NA>     <NA>     <NA>  <NA>
# 43735         21           4.6   19.916667     <NA>     <NA>     <NA>  <NA>
# 43736         30           4.9   23.833333     <NA>     <NA>     <NA>  <NA>
# 43737         20           4.7   13.583333     <NA>     <NA>     <NA>  <NA>
# 43738         23           4.9   17.166667     <NA>     <NA>     <NA>  <NA>
#
#        Delivery_Time  Category   wait_time  order_hour  pickup_hour  \
# 0                120         2 -27460800.0           0            0
# 1                165         4 -27469440.0           0            0
# 2                130        14 -27460800.0           0            0
# 3                105         3 -27485280.0           0            0
# 4                150        15 -27470880.0           0            0
# ...              ...       ...         ...         ...          ...
# 43734            160      <NA> -27468000.0           0            0
# 43735            180      <NA> -27416160.0           0            0
# 43736             80      <NA> -27449280.0           0            0
# 43737            130      <NA> -27443520.0           0            0
# 43738            180      <NA> -27436320.0           0            0
#
#        day_of_week  is_weekend
# 0                5           1
# 1                4           0
# 2                5           1
# 3                1           0
# 4                5           1
# ...            ...         ...
# 43734            3           0
# 43735            2           0
# 43736            4           0
# 43737            0           0
# 43738            2           0
#
# [43594 rows x 14 columns]

# %% [markdown]
# # ML Model

# %%
def train_rf_model_mlflow(
    df,
    target='Delivery_Time',
    n_splits=5,
    random_state=42,
    experiment_name='random_forest',
    tracking_uri=None,
    param_grid=None,
    save_model=True,
    log_artifacts=False,   # <-- importante se seu MLflow artifact store estiver problemático
    max_search_iters=20
):
    # Validações básicas
    if target not in df.columns:
        raise ValueError(f"Target '{target}' não encontrado no DataFrame.")
    if df.empty:
        raise ValueError("DataFrame está vazio, não é possível treinar modelo.")

    X = df.drop(columns=[target])
    y = df[target]

    if X.shape[1] == 0:
        raise ValueError("Nenhuma feature disponível após remover o target.")
    if not pd.api.types.is_numeric_dtype(y):
        raise ValueError("Target precisa ser numérico para regressão.")

    # MLflow
    if tracking_uri:
        # Recomende formato file:///d:/caminho/no/windows
        mlflow.set_tracking_uri(tracking_uri)
    mlflow.set_experiment(experiment_name)

    # Param grid safe
    if param_grid is None:
        param_grid = {
            'n_estimators': [100, 200, 300],
            'max_depth': [None, 10, 20, 30],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4]
        }

    # calcula um n_iter seguro: conta só valores "list-like"
    try:
        lengths = []
        for v in param_grid.values():
            if hasattr(v, '__len__') and not isinstance(v, (str, bytes)):
                lengths.append(len(v))
            else:
                lengths.append(None)  # distribuições ou não contáveis
        # produto das dimensões contáveis
        prod = 1
        for L in lengths:
            if L is None:
                prod = None
                break
            prod *= max(1, L)
        if prod is None:
            computed_n_iter = max_search_iters
        else:
            computed_n_iter = min(max_search_iters, int(prod))
    except Exception:
        computed_n_iter = max_search_iters
    computed_n_iter = max(1, computed_n_iter)

    rmse_scorer = make_scorer(mean_squared_error, squared=False, greater_is_better=False)

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    base_rf = RandomForestRegressor(random_state=random_state, n_jobs=1)  # evita nested parallelism

    search = RandomizedSearchCV(
        estimator=base_rf,
        param_distributions=param_grid,
        cv=kf,
        scoring=rmse_scorer,
        n_iter=computed_n_iter,
        n_jobs=-1,
        return_train_score=True,
        random_state=random_state,
        verbose=1,
    )

    start_time = time.time()
    with mlflow.start_run() as run:
        run_id = run.info.run_id
        mlflow.log_param("n_splits", int(n_splits))
        mlflow.log_param("random_state", int(random_state))
        mlflow.log_param("computed_n_iter", int(computed_n_iter))
        mlflow.log_param("platform", str(platform.platform()))
        mlflow.log_param("python_version", str(sys.version.split()[0]))

        # fit
        search.fit(X, y)
        best_model = search.best_estimator_
        best_params = getattr(search, "best_params_", {})

        for k, v in best_params.items():
            mlflow.log_param(f"best_{k}", str(v))

        # OOF
        try:
            y_oof = cross_val_predict(best_model, X, y, cv=kf, n_jobs=-1)
            mae_oof = mean_absolute_error(y, y_oof)
            rmse_oof = np.sqrt(mean_squared_error(y, y_oof))
            r2_oof = r2_score(y, y_oof)
        except Exception as e:
            print(f"Erro em cross_val_predict: {e}")
            y_oof = np.zeros_like(y)
            mae_oof = rmse_oof = r2_oof = np.nan

        metrics = {'MAE_oof': float(mae_oof), 'RMSE_oof': float(rmse_oof), 'R2_oof': float(r2_oof)}
        for mk, mv in metrics.items():
            try:
                mlflow.log_metric(mk, mv)
            except Exception as e:
                print(f"mlflow.log_metric falhou para {mk}: {e}")

        # in-sample
        try:
            y_in = best_model.predict(X)
            metrics_in = {
                'MAE_in': float(mean_absolute_error(y, y_in)),
                'RMSE_in': float(np.sqrt(mean_squared_error(y, y_in))),
                'R2_in': float(r2_score(y, y_in))
            }
        except Exception as e:
            print(f"Erro em métricas in-sample: {e}")
            metrics_in = {'MAE_in': np.nan, 'RMSE_in': np.nan, 'R2_in': np.nan}
        for mk, mv in metrics_in.items():
            try:
                mlflow.log_metric(mk, mv)
            except Exception as e:
                print(f"mlflow.log_metric falhou para {mk}: {e}")

        # salvar modelo (tenta infer_signature, senão sem signature)
        if save_model:
            try:
                try:
                    signature = infer_signature(X, y)
                    mlflow.sklearn.log_model(best_model, name="model", signature=signature)
                except Exception:
                    mlflow.sklearn.log_model(best_model, name="model")
            except Exception as e:
                print(f"mlflow.sklearn.log_model falhou: {e}")

        # Figure: feature importance
        try:
            fi = best_model.feature_importances_
            fig, ax = plt.subplots(figsize=(10, max(4, len(X.columns)*0.25)))
            sorted_idx = np.argsort(fi)
            ax.barh(np.array(X.columns)[sorted_idx], fi[sorted_idx])
            ax.set_title("Feature Importance")
            plt.tight_layout()
            if log_artifacts:
                mlflow.log_figure(fig, "feature_importance.png")
            plt.close(fig)
        except Exception as e:
            print(f"feature importance failed: {e}")

        # Scatter OOF
        try:
            fig, ax = plt.subplots(figsize=(6, 6))
            ax.scatter(y, y_oof, alpha=0.5)
            ax.plot([y.min(), y.max()], [y.min(), y.max()], '--', lw=1)
            ax.set_xlabel("True")
            ax.set_ylabel("OOF Pred")
            ax.set_title("OOF")
            plt.tight_layout()
            if log_artifacts:
                mlflow.log_figure(fig, "y_true_vs_pred.png")
            plt.close(fig)
        except Exception as e:
            print(f"scatter OOF failed: {e}")

        # log sample dataset (opcional)
        if log_artifacts:
            try:
                with tempfile.TemporaryDirectory() as tmpdir2:
                    sample_path = os.path.join(tmpdir2, "data_sample.csv")
                    df.sample(min(len(df), 200), random_state=random_state).to_csv(sample_path, index=False)
                    mlflow.log_artifact(sample_path, name="data_sample")
            except Exception as e:
                print(f"log sample dataset failed: {e}")

        duration = time.time() - start_time
        mlflow.log_metric("train_duration_seconds", float(duration))
        run_info = {"run_id": run_id, "experiment_id": run.info.experiment_id}

    return best_model, {**metrics, **metrics_in}, run_info

# %%
best_model, metrics_all, run_info = train_rf_model_mlflow(df_final)
print(metrics_all)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\igor-\anaconda3\envs\mlflow\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
#   warnings.warn(
# c:\Users\igor-\anaconda3\envs\mlflow\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the train scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
#   warnings.warn(
# c:\Users\igor-\anaconda3\envs\mlflow\Lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/09/10 15:20:56 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# mlflow.sklearn.log_model falhou: Could not find a registered artifact repository for: d:\igor-\GitHub\tech_challenge_ml_engineer_phase3\notebooks\mlruns/1/models/m-cdbb584c82b84cbdb49bcfd1655601d3/artifacts. Currently registered schemes are: ['', 'file', 's3', 'r2', 'gs', 'wasbs', 'ftp', 'sftp', 'dbfs', 'hdfs', 'viewfs', 'runs', 'models', 'http', 'https', 'mlflow-artifacts', 'abfss']
# 🏃 View run placid-midge-82 at: http://127.0.0.1:8080/#/experiments/1/runs/b847c7ee2d994e4e9504b55525fbd5d1
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/1
# {'MAE_oof': 31.62223504047127, 'RMSE_oof': 42.41522874442337, 'R2_oof': 0.33316764504798435, 'MAE_in': 21.835322751481502, 'RMSE_in': 29.967943403533372, 'R2_in': 0.6671206026734897}

# %%
# visualizing the best model parameters
best_model
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=4, min_samples_split=5,
#                       n_estimators=300, n_jobs=1, random_state=42)

# %%
# visualizing the metrics
metrics_all
# Out:
# {'MAE_oof': 31.62223504047127,
#  'RMSE_oof': 42.41522874442337,
#  'R2_oof': 0.33316764504798435,
#  'MAE_in': 21.835322751481502,
#  'RMSE_in': 29.967943403533372,
#  'R2_in': 0.6671206026734897}

# %% [markdown]
# ## Quick ETA model summary
# """
# * MAE_oof ~18min → avg prediction error out-of-sample ~18min
# * RMSE_oof ~23 → some big errors inflate the average
# * R2_oof 0.80 → explains 80% of variance out-of-sample
#
# * MAE_in 6.6, RMSE_in 8.6, R2_in 0.97 → clear overfitting
#
# 🔧 Improvements:
# - More training data
# - Regularization (increase min_samples_leaf/split, decrease max_depth)
# - Feature engineering (delivery time, weather, holidays)
# - Handle outliers
# - Try Gradient Boosting (XGBoost, LightGBM, CatBoost)
# """

# %% [markdown]
# ## Saving Model

# %%
def save_model_mlflow(model,
                      path="../mlruns/models/rfr_model_v1",
                      run_name="rf_save_v1",
                      artifact_path_name="rf_model",
                      log_to_mlflow=True):
    """
    Salva o modelo localmente em `path` e tenta logar no MLflow.
    - path: caminho local onde será salvo (resolved -> absolute)
    - run_name: nome do run quando for logar no MLflow
    - artifact_path_name: subpasta/artifact path dentro do run para log_model
    - log_to_mlflow: se False, não tenta logar no MLflow (só salva localmente)
    """

    # 1) Salva localmente no formato MLflow (garante que diretório exista)
    local_path = Path(path).resolve()
    local_path.mkdir(parents=True, exist_ok=True)

    try:
        # mlflow.sklearn.save_model salva o modelo no formato MLflow localmente
        mlflow.sklearn.save_model(sk_model=model, path=str(local_path))
        print(f"Modelo salvo localmente em: {local_path}")
    except Exception as e:
        print(f"Falha ao salvar modelo localmente em {local_path}: {e}")
        raise

    # 2) Se pediram para logar no MLflow, tentamos com cautela
    if not log_to_mlflow:
        print("log_to_mlflow=False -> pulando upload para MLflow.")
        return

    # Abre um run e verifica se o artifact_uri está em formato aceitável
    try:
        with mlflow.start_run(run_name=run_name) as run:
            artifact_uri = run.info.artifact_uri  # onde o MLflow quer gravar artefatos
            print("Run artifact_uri (raw):", artifact_uri)

            # Verifica se o artifact_uri tem esquema (file://, s3://, gs://, http://, etc.)
            if "://" not in artifact_uri:
                print(
                    f"Artifact URI sem esquema detectada: '{artifact_uri}'. "
                    "Provavelmente o tracking server não está configurado corretamente. "
                    "Pulando mlflow.sklearn.log_model() para evitar exceção."
                )
                return

            # Se chegou aqui, tentamos logar o modelo (usa artifact_path correto)
            try:
                mlflow.sklearn.log_model(sk_model=model, artifact_path=artifact_path_name)
                print(f"Modelo logado no MLflow em artifact_path='{artifact_path_name}'")
            except Exception as e:
                print(f"mlflow.sklearn.log_model falhou: {e}")
                # não re-raise porque já salvamos localmente
    except Exception as e:
        print(f"Falha ao iniciar run no MLflow: {e}")
        # não re-raise; o artefato local já está salvo

# %%
save_model_mlflow(
    model=best_model,
    path="../mlruns/models/rfr_model_v1",
    run_name="rf_save_v1"
)
# Out:
# Modelo salvo localmente em: D:\igor-\GitHub\tech_challenge_ml_engineer_phase3\mlruns\models\rfr_model_v1
# Run artifact_uri (raw): d:\igor-\GitHub\tech_challenge_ml_engineer_phase3\notebooks\mlruns/1/c8f1361ef27942f3a7cf6de98968f636/artifacts
# Artifact URI sem esquema detectada: 'd:\igor-\GitHub\tech_challenge_ml_engineer_phase3\notebooks\mlruns/1/c8f1361ef27942f3a7cf6de98968f636/artifacts'. Provavelmente o tracking server não está configurado corretamente. Pulando mlflow.sklearn.log_model() para evitar exceção.
# 🏃 View run rf_save_v1 at: http://127.0.0.1:8080/#/experiments/1/runs/c8f1361ef27942f3a7cf6de98968f636
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/1

# %% [markdown]
# # Predict

# %% [markdown]
# ## Random input generator (for testing)

# %%
def generate_random_input(
    df: pd.DataFrame,
    n_samples: int = 1,
    random_state: Optional[int] = None
) -> pd.DataFrame:
    """
    Generate random values within the [min, max] range of each numeric column in the DataFrame.
    Useful for creating artificial data to test a model with `.predict()`.

    Args:
        df (pd.DataFrame): DataFrame with only numeric columns.
        n_samples (int, optional): Number of rows to generate. Defaults to 1.
        random_state (int, optional): Seed for reproducibility. Defaults to None.

    Returns:
        pd.DataFrame: DataFrame with `n_samples` rows and the same columns as `df`,
                      excluding 'Delivery_Time' if present.
    """
    rng = np.random.default_rng(seed=random_state)
    random_data = {}

    for col in df.select_dtypes(include=np.number).columns:
        col_min = df[col].min()
        col_max = df[col].max()
        random_data[col] = rng.uniform(low=col_min, high=col_max, size=n_samples)

    random_df = pd.DataFrame(random_data)

    # Remove 'Delivery_Time' if it exists
    if 'Delivery_Time' in random_df.columns:
        random_df = random_df.drop(columns='Delivery_Time')

    return random_df

# %%
df_random = generate_random_input(df_final)
df_random
# Out:
#    Agent_Age  Agent_Rating  Order_Time   Weather   Traffic   Vehicle  \
# 0  24.760346      4.214168    9.458808  2.747165  1.254481  1.239286
#
#        Area  Category     wait_time  order_hour  pickup_hour  day_of_week  \
# 0  2.406662  3.200298 -2.742983e+07         0.0          0.0     2.231564
#
#    is_weekend
# 0    0.751391

# %% [markdown]
# ## Load and Predict

# %%
def load_model(model_path: str):
    """
    Load a saved sklearn model from a local path or MLflow Tracking Server.

    Args:
        model_path (str): Path to the saved model.

    Returns:
        Model: Loaded sklearn model.
    """
    model = mlflow.sklearn.load_model(model_path)
    return model

# %%
def predict_model(model, input_df: pd.DataFrame) -> pd.Series:
    """
    Make predictions using a loaded sklearn model.

    Args:
        Model: Loaded sklearn model.
        input_df (pd.DataFrame): DataFrame containing input features for prediction.

    Returns:
        pd.Series: Predicted values for each row in `input_df`.
    """
    predictions = model.predict(input_df)
    return pd.Series(predictions, index=input_df.index)

# %%
model = load_model("../mlruns/models/rfr_model_v1")
preds = predict_model(input_df=df_random, model=model)
preds
# Out:
# 0    117.335247
# dtype: float64

# %% [markdown]
# ## Serve Model API

# %%
# --- Serve Model ---
serve_port = 5000
serve_script_path = Path("../src/api_server.py").resolve()
process_serve = subprocess.Popen([sys.executable, str(serve_script_path)])
print(f"MLflow model serving started with PID {process_serve.pid}")
print(f"Access the model API at http://{server_host}:{serve_port}/invocations")
# Out:
# MLflow model serving started with PID 6684
# Access the model API at http://127.0.0.1:5000/invocations

# %% [markdown]
# ## Test API

# %%
def send_random_input_to_api(
    df: pd.DataFrame,
    url: str = "http://127.0.0.1:5000/invocations",
    n_samples: int = 1,
    random_state: int = None
) -> Dict[str, Any]:
    """
    Generate random input data based on the numeric ranges of a DataFrame,
    convert it to JSON, and send it to a REST API endpoint.

    Args:
        df (pd.DataFrame): DataFrame with numeric columns to base the random data on.
        url (str, optional): API endpoint to send the request. Defaults to local host.
        n_samples (int, optional): Number of random rows to generate. Defaults to 1.
        random_state (int, optional): Seed for reproducibility. Defaults to None.

    Returns:
        dict: JSON response from the API.
    """
    # Generate random input
    X_fake = generate_random_input(df, n_samples=n_samples, random_state=random_state)

    # Convert to JSON payload
    payload = json.loads(X_fake.to_json(orient="split"))

    # Send POST request
    try:
        response = requests.post(url, json={"dataframe_split": payload})
        response.raise_for_status()  # raise error for bad status codes
        return response.json()
    except requests.RequestException as e:
        print(f"❌ Request failed: {e}")
        return {"error": str(e)}

# %% [markdown]
# ## Predict Response

# %%
response = send_random_input_to_api(df_final, n_samples=1)
print(response)
# Out:
# ❌ Request failed: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /invocations (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000029A44994F50>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# {'error': "HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /invocations (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000029A44994F50>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))"}
