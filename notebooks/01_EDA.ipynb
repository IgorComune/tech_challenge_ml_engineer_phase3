# %% [markdown]
# # Objectives
# 1. ETA Prediction = customer satisfaction
# 2. Productivity = reducing operating costs
# 3. Anomalies = preventing hidden losses
# 4. Problematic areas = strategic planning of the logistics network

# %% [markdown]
# # Imports

# %% [markdown]
# ** IMPORTANT **
# * EXECUTE THIS INSIDE THE TERMINAL: mlflow server --host 127.0.0.1 --port 8080

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import os
from geopy.distance import geodesic
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
import matplotlib.pyplot as plt
import time
import json
import tempfile
import platform
import sys

import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer

mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")

# %% [markdown]
# # EDA Part 1 - Understanding the Dataset

# %%
df = pd.read_csv(r'../data/raw/amazon_delivery.csv')
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
# order_date, order_time and pickpu_time are string
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  object
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...

# %%
# missing values already spotted
df.describe()
# Out:
#           Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# count  43739.000000  43685.000000    43739.000000     43739.000000
# mean      29.567137      4.633780       17.210960        70.661177
# std        5.815155      0.334716        7.764225        21.475005
# min       15.000000      1.000000      -30.902872       -88.366217
# 25%       25.000000      4.500000       12.933298        73.170283
# 50%       30.000000      4.700000       18.551440        75.898497
# 75%       35.000000      4.900000       22.732225        78.045359
# max       50.000000      6.000000       30.914057        88.433452
#
#        Drop_Latitude  Drop_Longitude  Delivery_Time
# count   43739.000000    43739.000000   43739.000000
# mean       17.459031       70.821842     124.905645
# std         7.342950       21.153148      51.915451
# min         0.010000        0.010000      10.000000
# 25%        12.985996       73.280000      90.000000
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Agent_Age           0
# Agent_Rating       54
# Store_Latitude      0
# Store_Longitude     0
# Drop_Latitude       0
# Drop_Longitude      0
# Order_Date          0
# Order_Time          0
# Pickup_Time         0
# Weather            91
# Traffic             0
# Vehicle             0
# Area                0
# Delivery_Time       0
# Category            0
# dtype: int64

# %%
# considering that there are NaN values and considering that they represent less than 1% of the table, the lines are going to be dropped
df = df.dropna()

# %%
# confirming that there are no NaN values
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# order_date, order_time and pickup_time datatypes are wrong
# in order to solve this problem I wanna convert the 2 time columns to decimal and order date from string to datetime type
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

for col in ["Order_Time", "Pickup_Time"]:
    df[col] = pd.to_timedelta(df[col]).dt.total_seconds() / 3600

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43594 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43594 non-null  object
#  1   Agent_Age        43594 non-null  int64
#  2   Agent_Rating     43594 non-null  float64
#  3   Store_Latitude   43594 non-null  float64
#  4   Store_Longitude  43594 non-null  float64
#  5   Drop_Latitude    43594 non-null  float64
#  6   Drop_Longitude   43594 non-null  float64
#  7   Order_Date       43594 non-null  datetime64[ns]
#  8   Order_Time       43594 non-null  float64
#  9   Pickup_Time      43594 non-null  float64
#  10  Weather          43594 non-null  object
#  11  Traffic          43594 non-null  object
#  12  Vehicle          43594 non-null  object
#  13  Area             43594 non-null  object
#  14  Delivery_Time    43594 non-null  int64
#  15  Category         43594 non-null  object
# ...

# %%
# now we have 6 objects, 9 numeric e 1 datetime columns
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude Order_Date  Order_Time  Pickup_Time  \
# 0      22.765049       75.912471 2022-03-19       11.50    11.750000
# 1      13.043041       77.813237 2022-03-25       19.75    19.833333
# 2      12.924264       77.688400 2022-03-19        8.50     8.750000
# 3      11.053669       77.026494 2022-04-05       18.00    18.166667
# 4      13.012793       80.289982 2022-03-26       13.50    13.750000
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %% [markdown]
# # EDA Part 2 - Understanding the Dataset

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Analysing object type

# %%
def profile_object_columns(df):
    """
    Profile analysis for object (categorical) columns.
    Prints unique values and value counts > 1 with clear separation.
    """
    object_columns = df.select_dtypes(include=['object']).columns
    
    for column in object_columns:
        print(f"\n{'='*60}")
        print(f"Column: {column}")
        print(f"{'='*60}\n")
        
        # Unique values
        uniques = df[column].unique()
        print(f"Unique values ({len(uniques)}):")
        print(uniques)
        print(f"\n{'-'*60}\n")
        
        # Value counts sorted ascending, only values appearing more than once
        counts = df[column].value_counts()
        repeated_counts = counts[counts > 1].sort_values()
        if not repeated_counts.empty:
            print(f"Value counts (appearing more than once, ascending):")
            print(repeated_counts.to_string())
        else:
            print("No repeated values.")
        
        print(f"\n{'='*60}\n")


profile_object_columns(df)
# Out:
# ...
# Column: Order_ID
# ...
#
# Unique values (43594):
# ['ialx566343618' 'akqg208421122' 'njpu434582536' ... 'xnek760674819'
#  'cynl434665991' 'nsyz997960170']
#
# ------------------------------------------------------------
#
# No repeated values.
#
# ...
#
#
# ...
# Column: Weather
# ...
#
# Unique values (6):
# ['Sunny' 'Stormy' 'Sandstorms' 'Cloudy' 'Fog' 'Windy']
#
# ------------------------------------------------------------
#
# Value counts (appearing more than once, ascending):
# Weather
# Sunny         7067
# Windy         7211
# Sandstorms    7238
# Cloudy        7277
# Stormy        7366
# Fog           7435
#
# ...
#
#
# ...
# Column: Traffic
# ...
#
# Unique values (4):
# ['High ' 'Jam ' 'Low ' 'Medium ']
#
# ------------------------------------------------------------
#
# Value counts (appearing more than once, ascending):
# Traffic
# High        4294
# Medium     10614
# Jam        13710
# Low        14976
#
# ...
#
#
# ...
# Column: Vehicle
# ...
#
# Unique values (3):
# ['motorcycle ' 'scooter ' 'van']
#
# ...

# %% [markdown]
# #### Critical Points
# * Traffic: “High” = 4294, “Low” = 14976 → significant imbalance (~3.5x).
# * Vehicle: “van” = 3518, “motorcycle” = 25486 → notable imbalance (~7x).
# * Area: “Semi-Urban” = 152, “Metropolitian” = 32592 → extreme imbalance (~215x).
# * Impact: These columns can bias ML models or statistical analyses; consider resampling, grouping categories, or weighting.

# %% [markdown]
# #### Treating Objects
# * Only numbers are understood by ML models

# %%
# visualizing the object datatype columns
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Order_ID', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Category'], dtype='object')

# %%
df['Order_ID']
# Out:
# 0        ialx566343618
# 1        akqg208421122
# 2        njpu434582536
# 3        rjto796129700
# 4        zguw716275638
#              ...
# 43734    jlxf819993117
# 43735    aevx342135787
# 43736    xnek760674819
# 43737    cynl434665991
# 43738    nsyz997960170
# Name: Order_ID, Length: 43594, dtype: object

# %%
# the Order_ID column won't be considered because it's not a feature itself.
df = df.drop(columns='Order_ID')
df.columns
# Out:
# Index(['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
#        'Drop_Latitude', 'Drop_Longitude', 'Order_Date', 'Order_Time',
#        'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
#        'Category'],
#       dtype='object')

# %%
def encode_object_columns_to_numeric(df, output_dir="../data/processed/mappings"):
    """
    Convert object-type columns in a pandas DataFrame to numeric values using LabelEncoder.
    For each processed column, exports a CSV file with the mapping between index and category.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Input DataFrame with object columns to be encoded
    output_dir : str, default "../data/processed/mappings"
        Directory where CSV mapping files will be saved
        
    Returns:
    --------
    pandas.DataFrame
        DataFrame with object columns converted to numeric
    dict
        Dictionary containing the LabelEncoder objects for each column (for inverse transform if needed)
    """
    
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Make a copy of the dataframe to avoid modifying the original
    df_encoded = df.copy()
    
    # Dictionary to store encoders for each column
    encoders = {}
    
    # Get object-type columns
    object_columns = df.select_dtypes(include=['object']).columns
    
    print(f"Found {len(object_columns)} object columns to encode: {list(object_columns)}")
    
    # Process each object column
    for column in object_columns:
        print(f"Processing column: {column}")
        
        # Handle missing values - LabelEncoder doesn't handle NaN
        non_null_mask = df[column].notna()
        
        if non_null_mask.sum() == 0:
            print(f"Warning: Column '{column}' has no non-null values. Skipping.")
            continue
            
        # Initialize LabelEncoder
        le = LabelEncoder()
        
        # Fit and transform non-null values
        encoded_values = le.fit_transform(df[column][non_null_mask])
        
        # Create the encoded column (initialize with NaN for null values)
        df_encoded[column] = pd.Series(index=df.index, dtype='float64')
        df_encoded.loc[non_null_mask, column] = encoded_values
        
        # Store the encoder
        encoders[column] = le
        
        # Create mapping DataFrame
        mapping_df = pd.DataFrame({
            'index': range(len(le.classes_)),
            'category': le.classes_
        })
        
        # Export mapping to CSV
        csv_filename = os.path.join(output_dir, f"{column}_mapping.csv")
        mapping_df.to_csv(csv_filename, index=False)
        
        print(f"Mapping for '{column}' saved to: {csv_filename}")
        print(f"Unique categories found: {len(le.classes_)}")
    
    return df_encoded, encoders

# %%
# Apply the encoding function
df_encoded, encoders_dict = encode_object_columns_to_numeric(df)
df_encoded.head()
# Out:
# Found 5 object columns to encode: ['Weather', 'Traffic', 'Vehicle', 'Area', 'Category']
# Processing column: Weather
# Mapping for 'Weather' saved to: ../data/processed/mappings\Weather_mapping.csv
# Unique categories found: 6
# Processing column: Traffic
# Mapping for 'Traffic' saved to: ../data/processed/mappings\Traffic_mapping.csv
# Unique categories found: 4
# Processing column: Vehicle
# Mapping for 'Vehicle' saved to: ../data/processed/mappings\Vehicle_mapping.csv
# Unique categories found: 3
# Processing column: Area
# Mapping for 'Area' saved to: ../data/processed/mappings\Area_mapping.csv
# Unique categories found: 4
# Processing column: Category
# Mapping for 'Category' saved to: ../data/processed/mappings\Category_mapping.csv
# Unique categories found: 16
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  Drop_Latitude  \
# 0         37           4.9       22.745049        75.892471      22.765049
# ...

# %% [markdown]
# ### Analysing numeric type

# %%
def detect_outliers_iqr(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return series[(series < lower_bound) | (series > upper_bound)]

def profile_analyser(df):
    """
    Compact profile analysis of numerical columns: focuses on variability, skewness, outliers, and uniqueness.
    """
    numeric_columns = df.select_dtypes(include=[np.number]).columns
    profile = {}

    for col in numeric_columns:
        series = df[col].dropna()
        
        profile[col] = {
            'mean': series.mean(),
            'std': series.std(),
            'skewness': series.skew(),
            'outliers_count': len(detect_outliers_iqr(series)),
            'unique_count': series.nunique(),
            'unique_pct': (series.nunique() / len(series)) * 100 if len(series) > 0 else 0,
            'range': series.max() - series.min()
        }
    
    return pd.DataFrame(profile).T

# %%
numeric_analysis = profile_analyser(df)
numeric_analysis
# Out:
#                        mean        std  skewness  outliers_count  \
# Agent_Age         29.555719   5.760689 -0.014471             0.0
# Agent_Rating       4.635287   0.313827 -1.793118          1132.0
# Store_Latitude    17.244769   7.690005 -1.055690           151.0
# Store_Longitude   70.768898  21.128773 -2.954381          4301.0
# Drop_Latitude     17.461540   7.338199 -0.700486             0.0
# Drop_Longitude    70.832489  21.128940 -2.954371          6468.0
# Order_Time        17.917196   4.841461 -1.046237           429.0
# Pickup_Time       17.629523   5.358668 -1.263466          1254.0
# Delivery_Time    124.916433  51.941975  0.188318            79.0
#
#                  unique_count  unique_pct       range
# Agent_Age                20.0    0.045878   19.000000
# Agent_Rating             26.0    0.059641    2.500000
# Store_Latitude          489.0    1.121714   61.816929
# Store_Longitude         389.0    0.892325   88.433452
# ...

# %%
numeric_analysis.to_csv(r'../data/processed/profile_analyser_numeric_columns.csv')

# %% [markdown]
# #### Critical Points
#
#
# Agent_Age: discard → 0% variability, provides no useful information.
#
# Agent_Rating: discard or investigate → almost constant (0.1% variability), many outliers (1132) and negative skew; concentrated at high values – consider converting into categories.
#
# Order_Time: transform into derived features (hour of day, shift, delay) → low variability (0.4%), negative skew (-1.05) and 429 outliers; raw values not useful.
#
# Pickup_Time: transform into derived features (waiting time, delay) → low variability (0.4%), negative skew (-1.26) and 1254 outliers; raw values not useful.
#
# Delivery_Time: transform into performance feature (delivery time) → low variability (0.2%) and 79 outliers; outliers may represent critical deliveries.

# %% [markdown]
# ## Multivariate Analysis - Correlations

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43594 entries, 0 to 43738
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Agent_Age        43594 non-null  int64
#  1   Agent_Rating     43594 non-null  float64
#  2   Store_Latitude   43594 non-null  float64
#  3   Store_Longitude  43594 non-null  float64
#  4   Drop_Latitude    43594 non-null  float64
#  5   Drop_Longitude   43594 non-null  float64
#  6   Order_Date       43594 non-null  datetime64[ns]
#  7   Order_Time       43594 non-null  float64
#  8   Pickup_Time      43594 non-null  float64
#  9   Weather          43594 non-null  float64
#  10  Traffic          43594 non-null  float64
#  11  Vehicle          43594 non-null  float64
#  12  Area             43594 non-null  float64
#  13  Delivery_Time    43594 non-null  int64
#  14  Category         43594 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(2)
# memory usage: 5.3 MB

# %%
df_encoded.columns
# Out:
# Index(['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
#        'Drop_Latitude', 'Drop_Longitude', 'Order_Date', 'Order_Time',
#        'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
#        'Category'],
#       dtype='object')

# %%
# table for correlation
df_for_corr = df_encoded[['Agent_Age', 'Agent_Rating', 'Order_Date', 'Order_Time',
       'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
       'Category']] # latitude and longitude removed
correlation_matrix = df_for_corr.corr()

# %% [markdown]
# #### Correlation Matrix

# %%
# Setting style
plt.figure(figsize=(12, 10))
sns.set_style("whitegrid")

# Heatmap
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))  # masking upper triangle

sns.heatmap(correlation_matrix, 
           annot=True,                    
           fmt='.2f',                     
           cmap='RdBu_r',                 
           center=0,                      
           square=True,                   
           mask=mask,                     
           cbar_kws={'label': 'Correlation Coefficient'},
           annot_kws={'size': 10, 'weight': 'bold'})

plt.title('Feature Correlation Matrix\nDelivery Dataset Analysis', 
         fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Features', fontsize=12, fontweight='bold')
plt.ylabel('Features', fontsize=12, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Distance

# %%
df.columns
# Out:
# Index(['Agent_Age', 'Agent_Rating', 'Store_Latitude', 'Store_Longitude',
#        'Drop_Latitude', 'Drop_Longitude', 'Order_Date', 'Order_Time',
#        'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time',
#        'Category'],
#       dtype='object')

# %%
def distance(row):
    store_coord = (row['Store_Latitude'], row['Store_Longitude'])
    drop_coord = (row['Drop_Latitude'], row['Drop_Longitude'])
    return geodesic(store_coord, drop_coord).kilometers

# %%
df_encoded['distance'] = df_encoded.apply(distance, axis=1)

# %%
df_encoded = df_encoded.drop(columns=['Store_Latitude', 'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude'])
df_encoded.head()
# Out:
#    Agent_Age  Agent_Rating Order_Date  Order_Time  Pickup_Time  Weather  \
# 0         37           4.9 2022-03-19       11.50    11.750000      4.0
# 1         34           4.5 2022-03-25       19.75    19.833333      3.0
# 2         23           4.4 2022-03-19        8.50     8.750000      2.0
# 3         38           4.7 2022-04-05       18.00    18.166667      4.0
# 4         32           4.6 2022-03-26       13.50    13.750000      0.0
#
#    Traffic  Vehicle  Area  Delivery_Time  Category   distance
# 0      0.0      0.0   3.0            120       2.0   3.020737
# 1      1.0      1.0   0.0            165       4.0  20.143737
# 2      2.0      0.0   3.0            130      14.0   1.549693
# 3      3.0      0.0   0.0            105       3.0   7.774497
# 4      0.0      1.0   0.0            150      15.0   6.197898

# %%
def create_time_features(df):
    """
    Cria features temporais para previsão de ETA ou Delivery_Time:
    - Wait_Time (em minutos)
    - Order_Hour, Pickup_Hour
    - Day_of_Week, Is_Weekend
    E remove colunas originais usadas no cálculo.
    """
    df = df.copy()
    
    # Converter Order_Date e Pickup_Time para datetime
    df['Order_Date'] = pd.to_datetime(df['Order_Date'])
    df['Pickup_Time'] = pd.to_datetime(df['Pickup_Time'])
    
    # Features temporais
    df['Wait_Time'] = (df['Pickup_Time'] - df['Order_Date']).dt.total_seconds() / 60  # em minutos
    df['Day_of_Week'] = df['Order_Date'].dt.dayofweek
    df['Is_Weekend'] = df['Day_of_Week'].isin([5,6]).astype(int)
    
    # Drop das colunas originais que não serão mais usadas
    df = df.drop(columns=['Order_Date', 'Pickup_Time'])
    
    return df

# %%
df_final = create_time_features(df_encoded)
df_final
# Out:
#        Agent_Age  Agent_Rating  Order_Time  Weather  Traffic  Vehicle  Area  \
# 0             37           4.9   11.500000      4.0      0.0      0.0   3.0
# 1             34           4.5   19.750000      3.0      1.0      1.0   0.0
# 2             23           4.4    8.500000      2.0      2.0      0.0   3.0
# 3             38           4.7   18.000000      4.0      3.0      0.0   0.0
# 4             32           4.6   13.500000      0.0      0.0      1.0   0.0
# ...          ...           ...         ...      ...      ...      ...   ...
# 43734         30           4.8   11.583333      5.0      0.0      0.0   0.0
# 43735         21           4.6   19.916667      5.0      1.0      0.0   0.0
# 43736         30           4.9   23.833333      0.0      2.0      1.0   0.0
# 43737         20           4.7   13.583333      0.0      0.0      0.0   0.0
# 43738         23           4.9   17.166667      1.0      3.0      1.0   0.0
#
# ...

# %% [markdown]
# # ML Model

# %%
def train_rf_model_mlflow(
    df,
    target='Delivery_Time',
    n_splits=5,
    random_state=42,
    experiment_name='random_forest',
    tracking_uri=None,
    param_grid=None,
    log_cv_results=True,
    save_model=True
):
    """
    Treina RandomForest com GridSearchCV + KFold e registra artefatos no MLflow.
    Correções importantes:
     - calcula grid_size corretamente (sem sum() em escalares)
     - usa tmpdir de forma consistente (cada artefato em seu contexto temporário)
     - converte numpy types para int/float antes de logar no MLflow
    Retorna:
     - best_model, metrics_dict, run_info
    """
    # -------------------------
    # Preparação MLflow
    # -------------------------
    if tracking_uri:
        mlflow.set_tracking_uri(tracking_uri)
    mlflow.set_experiment(experiment_name)
    
    # -------------------------
    # Separar X e y
    # -------------------------
    X = df.drop(columns=[target])
    y = df[target]
    
    # -------------------------
    # Param grid default
    # -------------------------
    if param_grid is None:
        param_grid = {
            'n_estimators': [100, 200],
            'max_depth': [None, 10, 20],
            'min_samples_split': [2, 5],
            'min_samples_leaf': [1, 2]
        }
    
    # -------------------------
    # Scorer correto: RMSE a MINIMIZAR
    # -------------------------
    rmse_scorer = make_scorer(mean_squared_error, squared=False, greater_is_better=False)
    
    # -------------------------
    # GridSearchCV com KFold
    # -------------------------
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
    base_rf = RandomForestRegressor(random_state=random_state)
    
    grid = GridSearchCV(
        estimator=base_rf,
        param_grid=param_grid,
        cv=kf,
        scoring=rmse_scorer,
        n_jobs=-1,
        return_train_score=True,
        verbose=1
    )
    
    # -------------------------
    # Iniciar run pai
    # -------------------------
    start_time = time.time()
    with mlflow.start_run() as parent_run:
        run_id = parent_run.info.run_id
        
        # Log metadata úteis (converte numpy types para int/str)
        # grid_size: produto das opções de cada hiperparâmetro (int)
        try:
            grid_size = int(np.prod([len(v) for v in param_grid.values()]))
        except Exception:
            grid_size = "unknown"
        
        mlflow.set_tag("model_type", "RandomForestRegressor")
        mlflow.log_param("n_splits", int(n_splits))
        mlflow.log_param("random_state", int(random_state))
        mlflow.log_param("grid_size", str(grid_size))
        
        # Log versions (sklearn, python)
        try:
            import sklearn
            mlflow.log_param("sklearn_version", str(sklearn.__version__))
        except Exception:
            pass
        mlflow.log_param("python_version", str(sys.version.split()[0]))
        mlflow.log_param("platform", str(platform.platform()))
        
        # Fit grid
        grid.fit(X, y)
        best_model = grid.best_estimator_
        best_params = grid.best_params_
        
        # Log best params (convert to simple types)
        for k, v in best_params.items():
            mlflow.log_param(f"best_{k}", str(v))
        
        # Log cv_results as CSV artifact (use a fresh tmpdir context)
        cv_results = pd.DataFrame(grid.cv_results_)
        with tempfile.TemporaryDirectory() as tmpdir:
            csv_path = os.path.join(tmpdir, "cv_results.csv")
            cv_results.to_csv(csv_path, index=False)
            mlflow.log_artifact(csv_path, artifact_path="cv_results")
        
        # If requested: create child runs for each grid combo (logs mean/std test score)
        if log_cv_results:
            for idx, row in cv_results.iterrows():
                params = row['params']
                mean_test = row.get('mean_test_score', None)
                std_test = row.get('std_test_score', None)
                mean_train = row.get('mean_train_score', None)
                with mlflow.start_run(nested=True, run_name=f"grid_{idx}"):
                    for pk, pv in params.items():
                        mlflow.log_param(pk, str(pv))
                    if mean_test is not None:
                        # mean_test may be numpy type; convert to float
                        mlflow.log_metric("mean_test_score", float(mean_test))
                    if std_test is not None:
                        mlflow.log_metric("std_test_score", float(std_test))
                    if mean_train is not None:
                        mlflow.log_metric("mean_train_score", float(mean_train))
        
        # -------------------------
        # Avaliação HONESTA (out-of-fold)
        # -------------------------
        y_oof = cross_val_predict(best_model, X, y, cv=kf, n_jobs=-1)
        mae_oof = mean_absolute_error(y, y_oof)
        rmse_oof = np.sqrt(mean_squared_error(y, y_oof))
        r2_oof = r2_score(y, y_oof)
        
        metrics = {
            'MAE_oof': float(mae_oof),
            'RMSE_oof': float(rmse_oof),
            'R2_oof': float(r2_oof)
        }
        for mk, mv in metrics.items():
            mlflow.log_metric(mk, mv)
        
        # Also compute in-sample (optimistic) metrics
        y_in = best_model.predict(X)
        metrics_in = {
            'MAE_in': float(mean_absolute_error(y, y_in)),
            'RMSE_in': float(np.sqrt(mean_squared_error(y, y_in))),
            'R2_in': float(r2_score(y, y_in))
        }
        for mk, mv in metrics_in.items():
            mlflow.log_metric(mk, mv)
        
        # -------------------------
        # Log model signature & save model
        # -------------------------
        try:
            signature = infer_signature(X, y)
            if save_model:
                mlflow.sklearn.log_model(best_model, artifact_path="model", signature=signature)
        except Exception:
            if save_model:
                mlflow.sklearn.log_model(best_model, artifact_path="model")
        
        # -------------------------
        # Feature importance figure
        # -------------------------
        try:
            fi = best_model.feature_importances_
            fig, ax = plt.subplots(figsize=(10, max(4, len(X.columns)*0.25)))
            sorted_idx = np.argsort(fi)
            ax.barh(np.array(X.columns)[sorted_idx], fi[sorted_idx])
            ax.set_title("Feature Importance")
            plt.tight_layout()
            mlflow.log_figure(fig, "feature_importance.png")
            plt.close(fig)
        except Exception:
            pass
        
        # -------------------------
        # Log a small sample of the dataset (for reproducibility/debug)
        # -------------------------
        try:
            with tempfile.TemporaryDirectory() as tmpdir2:
                sample_path = os.path.join(tmpdir2, "data_sample.csv")
                df.sample(min(len(df), 200), random_state=random_state).to_csv(sample_path, index=False)
                mlflow.log_artifact(sample_path, artifact_path="data_sample")
        except Exception:
            pass
        
        # -------------------------
        # Runtime and finish
        # -------------------------
        duration = time.time() - start_time
        mlflow.log_metric("train_duration_seconds", float(duration))
        
        run_info = {"run_id": run_id, "experiment_id": parent_run.info.experiment_id}
    
    return best_model, {**metrics, **metrics_in}, run_info

# %%
best_model, metrics_all, run_info = train_rf_model_mlflow(df_final)
print(metrics_all)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\igor-\anaconda3\envs\mlflow\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
#   warnings.warn(
# c:\Users\igor-\anaconda3\envs\mlflow\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the train scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
#   warnings.warn(
# 🏃 View run grid_0 at: http://127.0.0.1:8080/#/experiments/583033553980908902/runs/d6ea5df2f6dc4ae39d452dad2b7736e5
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/583033553980908902
# 🏃 View run grid_1 at: http://127.0.0.1:8080/#/experiments/583033553980908902/runs/0ce8330dd933448dbc40e423983dc460
# ...

# %%
best_model
# Out:
# RandomForestRegressor(random_state=42)

# %%
metrics_all
# Out:
# {'MAE_oof': 17.979822682020462,
#  'RMSE_oof': 23.232263194884773,
#  'R2_oof': 0.7999419298738094,
#  'MAE_in': 6.591869982107629,
#  'RMSE_in': 8.614022834219094,
#  'R2_in': 0.9724966830207292}

# %%
def save_model_mlflow(model, path="models/rf_model", run_name="rf_save"):
    """
    Salva um modelo treinado do sklearn (ex: RandomForestRegressor) no MLflow
    em um caminho local definido.

    Parâmetros:
    - model: objeto sklearn já treinado
    - path: caminho onde o modelo será salvo (string)
    - run_name: nome da run no MLflow
    """
    os.makedirs(path, exist_ok=True)

    with mlflow.start_run(run_name=run_name):
        # loga o modelo no tracking server (artefatos do experimento)
        mlflow.sklearn.log_model(model, name="rf_model")

        # salva também em caminho local
        mlflow.sklearn.save_model(model, path)

    print(f"✅ Modelo salvo no MLflow (artefatos) e no caminho local: {path}")

# %%
save_model_mlflow(best_model, path="../mlruns/models/rfr_model_v1")
# Out:
# 2025/09/09 19:56:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run rf_save at: http://127.0.0.1:8080/#/experiments/583033553980908902/runs/9bb790207cf54d47856286c94f632163
# 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/583033553980908902
# ✅ Modelo salvo no MLflow (artefatos) e no caminho local: ../mlruns/models/rfr_model_v1

# %% [markdown]
# # Predict

# %%
def generate_random_input(df: pd.DataFrame, n_samples: int = 1, random_state: int = None):
    """
    Gera valores aleatórios dentro do intervalo [min, max] de cada coluna numérica do DataFrame.
    Útil para criar dados artificiais e testar o modelo com .predict().
    
    Parâmetros:
    - df: DataFrame com apenas colunas numéricas
    - n_samples: número de linhas a gerar
    - random_state: semente para reprodutibilidade
    
    Retorna:
    - DataFrame com n_samples linhas e mesmas colunas do df
    """
    rng = np.random.default_rng(seed=random_state)
    random_data = {}

    for col in df.columns:
        col_min = df[col].min()
        col_max = df[col].max()
        
        random_data[col] = rng.uniform(low=col_min, high=col_max, size=n_samples)
    
    return pd.DataFrame(random_data).drop(columns='Delivery_Time')

# %%
df_random = generate_random_input(df_final)
df_random
# Out:
#    Agent_Age  Agent_Rating  Order_Time   Weather   Traffic   Vehicle  \
# 0  36.841797      2.800412     9.56119  0.557655  1.784696  0.426602
#
#        Area  Category     distance     Wait_Time  Day_of_Week  Is_Weekend
# 0  0.309454  1.756791  5543.606982 -2.743935e+07     2.273627    0.270604

# %%
import mlflow.sklearn

# Carrega o modelo salvo (pode ser local ou do MLflow Tracking Server)
model = mlflow.sklearn.load_model("../mlruns/models/rfr_model_v1")

# Faz inferência
preds = model.predict(df_random)
preds
# Out:
# array([149.])

# %%
# executar no terminal: mlflow models serve -m "mlruns/models/rfr_model_v1" -p 5000 --no-conda

# %%
import json
X_fake = generate_random_input(df_final, n_samples=1)
json_payload = X_fake.to_json(orient="split")
print(json_payload)
# Out:
# {"columns":["Agent_Age","Agent_Rating","Order_Time","Weather","Traffic","Vehicle","Area","Category","distance","Wait_Time","Day_of_Week","Is_Weekend"],"index":[0],"data":[[30.4647020939,4.837466789,3.7430443575,4.1914446831,1.9664557833,1.4638332508,2.0645351001,5.8047049384,6371.3029926142,-27470627.3983953148,2.0769445548,0.3321616623]]}

# %%
import json
import requests

# Supondo que X_fake é um DataFrame
payload = json.loads(X_fake.to_json(orient="split"))  # -> dataframe_split

url = "http://127.0.0.1:5000/invocations"
response = requests.post(url, json={"dataframe_split": payload})
print(response.json())
# Out:
# {'predictions': [104.15]}
